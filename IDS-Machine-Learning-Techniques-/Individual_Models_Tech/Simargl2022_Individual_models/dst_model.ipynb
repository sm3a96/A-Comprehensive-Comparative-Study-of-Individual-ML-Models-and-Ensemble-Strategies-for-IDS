# %%
from sklearn.tree import DecisionTreeClassifier
import time
import sys
sys.path.append('/home/ibibers/IDS Project/IDS-Machine-Learning-Techniques-')
from Simargl import data_preprocessing, evaluate_model, plot_confusion_matrix


# ---------------------------- Model Training and Evaluation ----------------------------
results = []
datasets, le = data_preprocessing()
for name, (X_tr, X_te, y_train , y_test) in datasets.items():
    print(f"\n----- Training Models for {name} -----")
    
    start_time = time.time()
    model1 = DecisionTreeClassifier()

    model1.fit(X_tr, y_train)
    train_end_time = time.time()

    final_predictions = model1.predict(X_te)
    pred_end_time = time.time()


    metrics = evaluate_model(y_test, final_predictions, f"Decision Tree Classifier Technique Ensemble ({name})")
    metrics['Training Time (s)'] = train_end_time - start_time
    metrics['Prediction Time (s)'] = pred_end_time - train_end_time
    metrics['Total Time (s)'] = pred_end_time - start_time
    results.append(metrics)

    plot_confusion_matrix(y_test, final_predictions, le.classes_, f"Confusion Matrix ({name})")
# Out:
# ----- Training Models for All Features -----
#
# Decision Tree Classifier Technique Ensemble (All Features) Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# ----- Training Models for IG Top 5 Features -----
#
# Decision Tree Classifier Technique Ensemble (IG Top 5 Features) Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# ----- Training Models for IG Top 10 Features -----
#
# Decision Tree Classifier Technique Ensemble (IG Top 10 Features) Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# ----- Training Models for KBest Top 5 Features -----
#
# Decision Tree Classifier Technique Ensemble (KBest Top 5 Features) Metrics:
# Accuracy: 0.9999805419457276
# Precision: 0.9999802255009673
# Recall: 0.9999805419457276
# F1 Score: 0.9999794523969192
# ----- Training Models for KBest Top 10 Features -----
#
# Decision Tree Classifier Technique Ensemble (KBest Top 10 Features) Metrics:
# Accuracy: 0.9999980541945728
# Precision: 0.9999980542021454
# Recall: 0.9999980541945728
# F1 Score: 0.9999980541945728

# %%
# ---------------------------- Summary and Save Results ----------------------------
import pandas as pd
summary = pd.DataFrame(results)
print("\nSummary of Results:")
print(summary)

summary.to_csv("Sim_DT_classifier_evaluation_summary.csv", index=False)
# Out:
# Summary of Results:
#                                                Model  Accuracy  Precision  \
# 0  Decision Tree Classifier Technique Ensemble (A...  1.000000   1.000000
# 1  Decision Tree Classifier Technique Ensemble (I...  1.000000   1.000000
# 2  Decision Tree Classifier Technique Ensemble (I...  1.000000   1.000000
# 3  Decision Tree Classifier Technique Ensemble (K...  0.999981   0.999980
# 4  Decision Tree Classifier Technique Ensemble (K...  0.999998   0.999998
#
#      Recall  F1 Score  Training Time (s)  Prediction Time (s)  Total Time (s)
# 0  1.000000  1.000000          58.519354             0.135913       58.655267
# 1  1.000000  1.000000          16.526003             0.065948       16.591951
# 2  1.000000  1.000000          29.222895             0.083770       29.306665
# 3  0.999981  0.999979          10.290201             0.081156       10.371357
# 4  0.999998  0.999998          67.021773             0.111130       67.132904
