# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
import time
import sys
sys.path.append('/home/ibibers/IDS Project/IDS-Machine-Learning-Techniques-')
from Simargl import data_preprocessing, evaluate_model, plot_confusion_matrix

# ---------------------------- Model Training and Evaluation ----------------------------
results = []
datasets, le = data_preprocessing()
for name, (X_tr, X_te, y_train , y_test) in datasets.items():
    print(f"\n----- Training Models for {name} -----")
    

    start_time = time.time()
    model1 = RandomForestClassifier()
    
    model1.fit(X_tr, y_train)
    train_end_time = time.time()

    final_predictions = model1.predict(X_te)
    pred_end_time = time.time()


    metrics = evaluate_model(y_test, final_predictions, f" Random Forest Classifier Technique Ensemble ({name})")
    metrics['Training Time (s)'] = train_end_time - start_time
    metrics['Prediction Time (s)'] = pred_end_time - train_end_time
    metrics['Total Time (s)'] = pred_end_time - start_time
    results.append(metrics)

    plot_confusion_matrix(y_test, final_predictions, le.classes_, f"Confusion Matrix ({name})")
# Out:
# ----- Training Models for All Features -----
#
#  Random Forest Classifier Technique Ensemble (All Features) Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# ----- Training Models for IG Top 5 Features -----
#
#  Random Forest Classifier Technique Ensemble (IG Top 5 Features) Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# ----- Training Models for IG Top 10 Features -----
#
#  Random Forest Classifier Technique Ensemble (IG Top 10 Features) Metrics:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# ----- Training Models for KBest Top 5 Features -----
#
#  Random Forest Classifier Technique Ensemble (KBest Top 5 Features) Metrics:
# Accuracy: 0.9999810283970844
# Precision: 0.9999808627597885
# Recall: 0.9999810283970844
# F1 Score: 0.9999799297081721
# ----- Training Models for KBest Top 10 Features -----
#
#  Random Forest Classifier Technique Ensemble (KBest Top 10 Features) Metrics:
# Accuracy: 0.9999990270972864
# Precision: 0.9999990270991796
# Recall: 0.9999990270972864
# F1 Score: 0.9999990270972864

# %%
# ---------------------------- Summary and Save Results ----------------------------
import pandas as pd
summary = pd.DataFrame(results)
print("\nSummary of Results:")
print(summary)

summary.to_csv("Sim_Random Forest_classifier_evaluation_summary.csv", index=False)
# Out:
# Summary of Results:
#                                                Model  Accuracy  Precision  \
# 0   Random Forest Classifier Technique Ensemble (...  1.000000   1.000000
# 1   Random Forest Classifier Technique Ensemble (...  1.000000   1.000000
# 2   Random Forest Classifier Technique Ensemble (...  1.000000   1.000000
# 3   Random Forest Classifier Technique Ensemble (...  0.999981   0.999981
# 4   Random Forest Classifier Technique Ensemble (...  0.999999   0.999999
#
#      Recall  F1 Score  Training Time (s)  Prediction Time (s)  Total Time (s)
# 0  1.000000  1.000000        2607.515567            10.872340     2618.387907
# 1  1.000000  1.000000        1230.874402             8.643692     1239.518093
# 2  1.000000  1.000000        1707.357979             9.524983     1716.882962
# 3  0.999981  0.999980         831.590156             9.099942      840.690099
# 4  0.999999  0.999999        3029.853753            13.419275     3043.273028
